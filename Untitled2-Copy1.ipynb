# %%
import matplotlib.pyplot as mp
import pandas as pd
import numpy as np
import seaborn as sb
# %matplotlib inline

# %%
dl=pd.read_csv("Salary_dataset.csv")

# %%
dl.head(30)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
dl=dl.drop("Unnamed: 0",axis=1)
dl
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
dl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
dl.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dl.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
cor=dl.corr()
cor.style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_ace6b_row0_col0, #T_ace6b_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ace6b_row0_col1, #T_ace6b_row1_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ace6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ace6b_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_ace6b_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ace6b_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_ace6b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ace6b_row0_col1" class="data row0 col1" >0.978242</td>
#     </tr>
#     <tr>
#       <th id="T_ace6b_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_ace6b_row1_col0" class="data row1 col0" >0.978242</td>
#       <td id="T_ace6b_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
x=dl[['YearsExperience']]

# %%
y=dl['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#     YearsExperience
# 27              9.7
# 11              4.1
# 17              5.4
# 22              8.0
# 5               3.0
# 16              5.2
# 8               3.3
# 14              4.6
# 23              8.3
# 20              6.9
# 1               1.4
# 29             10.6
# 6               3.1
# 4               2.3
# 18              6.0
# 19              6.1
# 9               3.8
# 7               3.3
# 25              9.1
# 3               2.1
# 0               1.2
# 21              7.2
# 15              5.0
# 12              4.1

# %%
from sklearn.linear_model import LinearRegression

# %%
rmodel=LinearRegression()
rmodel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=rmodel.predict(x_test)
print(y_pred)
# Out:
# [ 40749.96184072 122700.62295594  64962.65717022  63100.14214487
#  115250.56285456 107800.50275317]

# %%
rmodel.intercept_
# Out:
# 25849.84163795526

# %%
rmodel.coef_
# Out:
# array([9312.57512673])

# %%
from sklearn.metrics import r2_score

# %%
r=r2_score(y_test,y_pred)
r*100
# Out:
# 98.8169515729126

# %%
sb.regplot(data=dl,x=y_test,y=y_pred,color='orange')
# Out:
# <AxesSubplot:xlabel='Salary'>
